# %%
import os               # Provides access to operating system-dependent functionality
import openai           # OpenAI's GPT-3 language model library
import requests         # Library for making HTTP requests
import httpx            # Library for making asynchronous HTTP requests
import spacy            # Library for natural language processing (NLP)
from bs4 import BeautifulSoup  # Library for web scraping and parsing HTML/XML documents
import asyncio

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from spacy.cli import download
download("en_core_web_sm")

# %%
async def generate_summary_chunk(chunk):
    # Define the conversation messages for the GPT-3 model
    messages = [
        {"role": "system", "content": "You are an AI language model tasked with summarizing articles in bullet points."},
        {"role": "user", "content": f"Here's an article chunk to summarize:\n\n{chunk}\n\n"},
        {"role": "user", "content": "Provide the most interesting and important elements in an easy to understand way."}
    ]
    
    summary = "-----------------"
    try:
        # Use an asynchronous HTTP client to make a POST request to the OpenAI API
        async with httpx.AsyncClient() as client:
            response = await client.post(
                    "https://api.openai.com/v1/chat/completions",  # API endpoint
                    json={
                        "model": "gpt-3.5-turbo-0301",  # Model name
                        "messages": messages,  # Conversation messages
                        "max_tokens": 100,  # Maximum number of tokens in the response
                        "temperature": 0.9,  # Sampling temperature
                        "n": 1,  # Number of completions to generate
                        "stream": False,  # Streaming mode
                        "stop": None,  # Stop sequence
                    },
                    headers={
                        "Content-Type": "application/json",
                        "Authorization": f"Bearer {openai.api_key}",  # API key for authorization
                },
            )
        response_data = response.json()
        summary = response_data['choices'][0]['message']['content'].strip()
    except Exception as e:
        print(e)

    return summary  # Return the summary text

# %%
def fetch_html(url: str) -> str:
    response = requests.get(url)  # Make an HTTP GET request to the URL
    return response.text          # Return the text content of the response

# %%
def extract_text(url_content):
    soup = BeautifulSoup(url_content, "html.parser")  # Parse the HTML content
    text_parts = []  # Initialize an empty list to store text parts
    # Iterate over all <p> and <div> elements in the HTML and extract their text content
    for p in soup.find_all(["p", "div"]):
        text_parts.append(p.text)
    # Join the text parts with newline characters and return the result
    return "\n".join(text_parts)

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# Define a function to extract keywords from a text string
def extract_keywords(text, num_keywords=5):
    doc = nlp(text)  # Process the text using the spaCy language model
    keywords = []  # Initialize an empty list to store keywords
    # Iterate over named entities in the text and extract keywords based on entity labels
    for ent in doc.ents:
        if ent.label_ in ["ORG", "PERSON", "GPE", "NORP"]:
            keywords.append(ent.text)
    # Iterate over tokens in the text and extract keywords based on part-of-speech tags
    for token in doc:
        if token.is_stop or token.is_punct:
            continue  # Skip stop words and punctuation
        if token.pos_ in ["NOUN", "ADJ", "VERB"] and len(keywords) < num_keywords:
            keywords.append(token.text)
    return keywords

# %%
print(os.environ.get("INIT_ENV"))
# Out:
# 123

# %%
url = "https://docs.espressif.com/projects/esp-idf/en/latest/esp32s3/security/secure-boot-v2.html"
url_content = fetch_html(url)  # Fetch the HTML content of the URL
article = extract_text(url_content)  # Extract the text content from the HTML
keywords = extract_keywords(article)  # Extract keywords from the article text
print(set(keywords))
print("\n")
# generate_summary_chunk([""])

chunk_size = 2800  # Define the maximum size of each article chunk
# Split the article into chunks based on the defined chunk size
article_chunks = [article[i:i + chunk_size] for i in range(0, len(article), chunk_size)]

# Use concurrency to process chunks simultaneously and generate summaries for each chunk
for chunk in article_chunks:
    x = await generate_summary_chunk(chunk)
    print(x)

# summaries = [await generate_summary_chunk(chunk) for chunk in article_chunks]
# final_summary = "\n".join(summaries)
# print(final_summary)
# print("\n")
# Out:
# {'1196', 'JTAG Debugging', 'Fatal Errors', 'Espressif Systems', 'Apps', 'eFuse', 'Flash Encryption', 'Reproducible Builds', 'Thread Local Storage', 'RSA Signature', 'the Project Configuration Menu', 'KEY_PURPOSE_X. Stores', 'PSS', 'Device Firmware Update', 'Windows', 'BINARY_FILE', 'Signatures\nSigning', 'Description', 'Get Started', 'KEY_DIGESTs', 'HSM', 'KEY_PURPOSE_X', 'Linker Script Generation', 'Generate', 'Contributions Guide', 'PDF\n\n\n\n\n\n\n\n\n\n ', 'RSA\nEnable', 'C++ Support', 'Offset\nSize', 'CONFIG_SECURE_BOOT_ALLOW_UNUSED_DIGEST_SLOTS', 'ESP32-S3', 'esptool.py', 'Remote Signing', 'Keyfile', 'Building', 'RSA-PSS Signature', 'Secure Boot verification', 'Bootloader Size', 'Signing Schemeâ\x80\x9d', 'OTA', 'my_secure_boot_signing_key.pem 3072', 'OpenThread', 'SECURE_BOOT_DIGEST2', 'Hardware Security Module', 'Firmware Upgrade', 'MMU', 'OSX/Linux', 'KB', 'RSA', 'RSA Public Modulus', 'CONFIG_SECURE_BOOT_INSECURE', 'Secure Boot V2', 'Copyrights', 'Server', 'RSA-PSS', 'byte', 'RSA-3072', 'RSA Public Exponent', 'Secure Boot Best', 'Secure Boot', 'the Secure Boot Configuration', 'ROM', 'Advanced', 'Shanghai) Co., Ltd.', 'USB Serial/JTAG Controller Console', 'PDF', 'Secure Boot Best Practices', 'API Guides', 'App Signing Scheme', 'Montgomery Multiplication', 'UART', 'Keys', 'Secure Boot V2ï\x83\x81\n\nImportant', 'eFuses', 'images & partition', 'â\x80\x93 offsets 36 to 812', 'SHA-256', 'JTAG Debuggingï\x83\x81'}
#
#
#
#
# - ESP-IDF Programming Guide offers guidance on programming for ESP32-S3 devices.
# - Secure Boot V2 is supported on ESP32-S3, and it protects devices from running unauthorized code by verifying software signatures.
# - RSA-PSS scheme is used for app and bootloader verification.
# - Secure Boot V2 involves multiple steps, including verifying the RSA-PSS signature of the second stage bootloader by the first stage bootloader.
# - The document offers guidelines on key management, key revocation, and best practices for
# -----------------
# - The bootloader checks the application image for verification using raw image data, signature blocks, and the eFuse. If verification fails, the boot process will be aborted.
# - The signature block has its own flash sector and starts on a 4KB aligned boundary.
# - The signature block contains a magic byte, version number byte, SHA-256 hash of the image content, RSA public modulus, RSA public exponent, pre-calculated R and M', RSA-PSS signature result, CRC32, and zero
# - The article describes the process of verifying the integrity and security of an ESP32-S3 device's bootloader and image.
# - The bootloader's signature block is validated by checking its first byte and stored CRC32 value.
# - The image is verified by checking its public key against that stored in the signature block, and by matching their SHA-256 hash digests.
# - Enabling secure boot and/or flash encryption can increase the bootloader's size and require updating partition table offset.
# - The device's eFuse
# - Secure Boot is a feature that helps protect against malicious attacks during the boot process of a device.
# - To enable Secure Boot in ESP32-S3, one needs to set "Enable hardware Secure Boot in bootloader" in the Project Configuration Menu.
# - The process requires generating a secure signing key and building a Secure Boot enabled bootloader.
# - It is important to use a strong random number source when generating the signing key to ensure a strong private key.
# - Secure Boot won't be enabled
# - "Secure Boot" is a feature that ensures that a device only boots software that has been signed with a specific key.
# - Once Secure Boot is enabled, any updates to the software must also be signed with a matching key.
# - Enabling Secure Boot also disables the USB-OTG USB stack in the device's ROM.
# - To generate a new Secure Boot signing key, a command prompt can be used, and the strength of the key depends on the randomness of the system that generates it.
# - ESP8266 devices can be secured using Secure Boot technology which involves generating signatures and appending them to firmware images.
# - The signing key used for Secure Boot should be generated on a system with high quality entropy and kept private at all times to maintain system security.
# - Secure Boot options such as flash encryption, disabling JTAG, disabling BASIC ROM interpreter, and disabling the UART bootloader encrypted flash access should be enabled to maximize security.
# - Between 1 and 3 RSA-3072 public key pairs should
# - This article discusses secure booting of ESP32 microcontrollers, which is an important step in preventing unauthorized access to devices.
# - Secure booting relies on the use of private keys to authenticate the bootloader and applications on the device.
# - The bootloader should be signed with all private keys needed for the life of the device, and apps should only be signed with a single private key to minimize the exposure of unused keys.
# - Key revocation is an important consideration in secure booting, and a conservative approach
# - The ROM code has a feature that revokes a public key if the signature verification fails, which provides strong resistance against physical attacks on devices
# - Secure Boot should be used with Flash Encryption to prevent time-of-check to time-of-use attacks
# - The Secure Boot V2 signature of apps can be checked on OTA update without enabling hardware Secure Boot, but it does not prevent attackers who can write to flash from bypassing the signature protection. It creates a chain of trust from the running app to the
# - It is essential for the initial app flashed to a device to be signed to prevent situations where no update is possible.
# - Only one valid signature block should be present in the first position of the app.
# - JTAG debugging is disabled when Secure Boot is enabled via eFuse.
# - It is recommended to use full hardware Secure Boot for application security needs.
# - To enable signed app verification, go to Project Configuration Menu -> Security features and ensure App Signing Scheme is RSA, and enable CONFIG_SECURE_SIGNED
# - ESP-IDF is a programming guide for the ESP32-S3 microcontroller.
# - It offers features for secure boot, flash encryption, and signed app verification.
# - The guide covers technical details, advanced features, and migration guides.
# - ESP-IDF also provides tools for debugging, unit testing, and running applications on a host.
# - Wi-Fi security and driver implementation are also covered.
# - The guide emphasizes key management and encryption best practices for more secure development.
# - Detailed instructions are provided for enabling
# - ESP32-S3 has a Secure Boot V2 feature that protects the device from running unauthorized code.
# - Secure Boot V2 uses RSA-PSS based app and bootloader verification to ensure the software is signed.
# - The RSA-PSS public key is stored on the device, and the corresponding RSA-PSS private key is kept at a secret place and never accessed by the device.
# - Up to three public keys can be generated and stored in the chip during manufacturing, and individual public keys can be permanently
# - ESP32-S3 includes a Secure Boot V2 feature that verifies the bootloader and application image on every boot as well as OTA updates.
# - Each image (bootloader and application) has a signature block that contains a signature of the previous image and a corresponding RSA-3072 public key.
# - The Secure Boot V2 process checks if Secure Boot is enabled, verifies the bootloader's signature block and image, then executes the bootloader and verifies the application image's signature block and image.
# - The signature
# - Secure Boot V2 scheme pads application images to ensure only verified contents are mapped in the internal address space.
# - A signature block appended to the signed application image contains the public key and the image digest for verification.
# - Verifying an image involves comparing the SHA-256 hash digest of the public key with the digest(s) saved in the eFuses, and matching the application image digest with the image digest in the signature block.
# - Enabling Secure Boot and/or flash encryption increases the size of
# - Secure Boot V2 is a feature that provides security to a system by verifying the authenticity of boot images.
# - Key blocks are used to store keys for authentication.
# - Revocation bits are used to revoke keys that are no longer needed.
# - Setting "Secure Boot Aggressive Revoke" will revoke a key if verification with it fails.
# - To enable Secure Boot V2, go to the Project Configuration Menu and enable "Enable hardware Secure Boot in bootloader".
# - Specify the path to the Secure Boot
# - Secure Boot is a feature that ensures that only authorized code runs on a device.
# - To enable Secure Boot on the ESP32-S3, a Secure Boot enabled bootloader needs to be built and flashed to the device.
# - Any subsequent updates to the bootloader or app will need to be signed with a key matching the digest already stored in eFuse.
# - Enabling Secure Boot or flash encryption disables the USB-OTG USB stack in the ROM.
# - A signing key needs to be generated to enable
# - Secure Boot system depends on a private signing key.
# - It's recommended to use a remote signing server for production builds.
# - Espsecure.py can be used to sign app images and partition table data for Secure Boot on a remote system.
# - Pre-calculated signatures can be used to generate a signature sector for an image.
# - An external Hardware Security Module (HSM) can be used to store private signing keys for security reasons.
# - The article discusses best practices for implementing Secure Boot in an ESP32 chip.
# - It suggests generating the signing key on a system with a quality source of entropy and keeping the key private at all times.
# - It also mentions enabling all Secure Boot options and using flash encryption to prevent local readout of flash contents.
# - Key management is also important, with recommendations to store RSA-3072 public key pairs separately and write protect the KEY_DIGEST eFuses after programming.
# - Multiple keys can be used
# - There are two approaches to key revocation (conservative and aggressive) which can protect against compromised private keys.
# - Revocation of keys may cause permanent device damage if all keys are revoked due to signature verification failure.
# - Secure Boot is integrated into the esp-idf build system, but standalone signatures can also be made using espsecure.py tool.
# - Using Secure Boot without Flash Encryption can make the system vulnerable to attacks. It is recommended to use both features together.
# - The Secure Boot V2 signature of apps can be checked without enabling the hardware Secure Boot option. This option uses the same app signature scheme but doesn't prevent an attacker from bypassing the signature protection.
# - The initial app flashed to the device must be signed to prevent any update issues.
# - Enabling CONFIG_SECURE_SIGNED_APPS_NO_SECURE_BOOT in the Project Configuration
# - Secure Boot V2 is a feature that protects devices from unauthorized code by checking that each piece of software being booted is signed.
# - Secure Boot V2 is implemented on ESP32-S3 and uses RSA-PSS based app and bootloader verification.
# - The RSA-PSS public key is stored on the device, while the corresponding RSA-PSS private key is kept secret and never accessed by the device.
# - Up to three public keys can be generated and stored in the chip during manufacturing.
# - ESP
# - Secure Boot V2 is an immune process to passive side-channel attacks such as timing or power analysis.
# - Each image has a separately generated signature block that is appended to the end of the image.
# - Up to 3 signature blocks can be appended to the bootloader or application image in ESP32-S3.
# - The application image is verified not only on every boot but also on each over the air (OTA) update.
# - Signature block format includes a magic byte, version number byte, padding bytes
# - The article talks about the process of securing an application image using Secure Boot V2 scheme.
# - Secure padding is applied to the application image to ensure that only verified contents are mapped in the internal address space.
# - A signature block is appended to the image and contains information like hash, signature and CRC32 for verification.
# - The image is verified by checking if the public key stored in any signature block is valid for the device and if the stored signature is valid for the image data stored in flash memory
# - Enabling Secure Boot and/or flash encryption will increase bootloader size, which may require updating partition table offset.
# - The Secure Boot feature can be enabled with hardware and software configurations.
# - Key programming includes setting the purpose of the key block, storing the SHA-256 digest of the public key, and enabling aggressive key revocation.
# - Revoking unused key digest slots is important to prevent attackers from adding trusted keys later.
# - The Secure Boot feature can be enabled through the Project Configuration
# Here are the key takeaways from the article chunk:
#
# - If you can't find a signing key, use espsecure.py generate_signing_key to generate one.
# - However, the private key may be weak if the random number source is weak, so it's recommended to use an industry standard encryption program for production environments.
# - Use idf.py bootloader to build a Secure Boot enabled bootloader, then idf.py flash to sign the app image using the signing key.
# - Secure Boot won
# - The article discusses the process of generating and using signing keys to ensure Secure Boot in ESP-IDF.
# - The strength of the signing key depends on the random number source of the system and the algorithm used.
# - For production devices, generating signing keys from a system with a quality entropy source and using the best available RSA-PSS key generation utilities is recommended.
# - Remote signing of images can be practiced to keep the signing key secure on a remote system rather than on the build machine.
# - Pre-cal
# - Secure Boot best practices are important to follow to prevent security breaches, including generating the signing key on a secure system, keeping the signing key private, and enabling all Secure Boot options.
# - Key management is necessary to ensure the security of RSA-3072 public key pairs, including storing them separately and write-protecting them.
# - Multiple keys can be used for the bootloader and apps, but it's important to ensure only necessary keys are used and to follow key revocation procedures.
# - To sign bootloaders and applications, use espsecure.py with the multiple private key signing feature.
# - When signing with multiple keys, sign them independently and store them separately to minimize the exposure of unused private keys.
# - If a private key is compromised, an OTA update with an application signed with a new private key can be sent and the device will verify and boot the new app.
# - An aggressive approach to key revocation can permanently brick a device if all keys are revoked due to signature verification
# - The article discusses how to use Secure Boot in the esp-idf build system to ensure app security on IoT devices.
# - Secure Boot ensures that only signed app images can run on the device, preventing unauthorized access.
# - To sign a binary image, you can use the espsecure.py tool with a private signing key.
# - It's recommended to use Secure Boot and Flash Encryption together to prevent attacks where flash contents are swapped after verification.
# - If you can't use hardware Secure Boot, you can still
# - The article explains how to enable Signed App Verification on ESP32-S3
# - To enable it, users need to go to the Project Configuration Menu -> Security features and ensure App Signing Scheme is RSA
# - There is an option to sign binaries during build, which can be enabled or disabled
# - All apps flashed must be signed, either during the build or after
# - JTAG debugging is disabled by default when Secure Boot is enabled
# - Secure Boot V2 uses RSA-PSS based app and
# - The ESP32-S3 chip has a Secure Boot V2 Process that verifies the bootloader and application binary images using a signature block with a separately generated RSA-3072 public key.
# - There is a facility to permanently revoke individual public keys, which can be configured conservatively or aggressively depending on the desired level of security.
# - No secrets are stored on the device, which makes it immune to passive side-channel attacks.
# - The application image is verified on every boot and over the air (OTA)
# - A signature block is used to ensure that software is only executed if it has been verified
# - The signature block contains a SHA-256 hash of the software, as well as its RSA-PSS signature result
# - Secure padding is used in Secure Boot V2 scheme to ensure that only verified software is mapped in internal memory
# - The signature sector is erased to allow for writing other signature blocks after the previous block
# - To verify an image, the public key stored in any signature block must be
# - Secure Boot is a feature that protects embedded systems from unauthorized access.
# - The verification process involves checking the signature of the bootloader image and the application image digest.
# - The Secure Boot's public key is stored in eFuses, making it tamper-proof.
# - The bootloader's size increases when secure boot is enabled, which may require updates to the partition table.
# - Unused key digest slots should be revoked to prevent an attacker from adding trusted keys later.
# - To enable Secure Boot, set "Enable
# - To enable Secure Boot on an ESP32-S3 chip, you need to set various configurations and build a Secure Boot enabled bootloader and app image.
# - The signing key used for Secure Boot should be generated using a strong random number source like openssl.
# - Once enabled, any updates to the bootloader or app must be signed with a key that matches the digest already stored in the chip's eFuse.
# - The chip's Secure Boot hardware will verify that the software bootloader and app have not been changed on
# - eFuses can be read protected, but disabling this behavior is not recommended if Secure Boot or flash encryption is enabled.
# - To generate a Secure Boot signing key, use the command provided by the build system or use a quality entropy source and RSA-PSS key generation utilities.
# - For production builds, it is recommended to use remote signing servers to sign app images & partition table data for Secure Boot, rather than having the signing key on the build machine.
# - If you have valid pre-calculated
# - ESP32 supports Secure Boot for enhanced security.
# - Secure Boot ensures that only signed binaries are executed during boot-up.
# - ESP32 allows for remote signing workflows, where the private signing key is not stored on the device.
# - A Hardware Security Module (HSM) can be used for enhanced security.
# - Best practices for Secure Boot include generating signing keys on systems with a quality source of entropy, enabling all Secure Boot options, and using Secure Boot in combination with flash encryption.
# - Key management involves
# - Private keys are used to sign applications and bootloaders in secure devices.
# - It is recommended to sign multiple private keys independently and store them separately.
# - If a private key is compromised, it is important to revoke it to maintain security.
# - There are two approaches to key revocation: conservative and aggressive.
# - The conservative approach involves updating the device with a new key and OTA update, while the aggressive approach involves burning an eFuse to revoke the key on failure.
# - Revoked keys can never be used again for verifying signatures of an image, providing strong resistance against physical attacks on the device.
# - Secure Boot should be used in conjunction with Flash Encryption to prevent time-of-check to time-of-use attacks.
# - The Secure Boot V2 signature of apps can be verified on OTA update, without enabling the hardware Secure Boot option, which may be desirable in cases where the delay of Secure Boot verification on startup is unacceptable.
# - The app flashed to the device must be signed
# - Secure Boot protects a device from running unauthorized code by checking that each piece of software that is being booted is signed.
# - Only the first public key in the signature block is used to verify updates if signature checking without Secure Boot is configured.
# - It is recommended to use full hardware Secure Boot unless you are certain that this option is sufficient for your application security needs.
# - When Secure Boot is enabled, JTAG debugging is disabled via eFuse.
# - Secure Boot V2 uses RSA-PSS based
# -----------------
# - The bootloader checks for a valid application image to execute.
# - If the verification fails, the bootloader looks for another image to verify.
# - The signature block is a flash sector containing a calculated signature over all bytes in the image.
# - Secure padding is used to ensure only verified contents are mapped in the internal address space.
# - A signature block is considered valid if the first byte is 0xe7 and a valid CRC32 is stored.
# - Verifying an image involves checking if the stored public key and signature match the image data read from flash.
# - To verify the image, we compare the SHA-256 hash digest of the public key with the digest(s) saved in the eFuses, and check if the application image digest matches the image digest in the signature block.
# - The size of the bootloader may increase when enabling Secure boot and/or flash encryption, which may require updating partition table offset.
# - The eFuse usage includes enabling
# - To enable Secure Boot V2, go to the Project Configuration Menu and set "Enable hardware Secure Boot in bootloader" to enable Secure Boot.
# - Specify the path to the Secure Boot signing key relative to the project directory and select the desired UART ROM download mode.
# - Generate a signing key via "espsecure.py generate_signing_key" if the signing key is not found during the first build.
# - For production environments, it is recommended to generate the key pair using openssl or another industry standard encryption
# - Secure Boot is a feature that ensures that only verified code can run on an embedded device.
# - Once Secure Boot is enabled, any updated bootloader or application must be signed with a key that matches the digest already stored in the device's eFuse.
# - Secure Boot and flash encryption will disable the USB-OTG USB stack in the device's ROM.
# - The strength of the Secure Boot system depends on keeping the signing key private.
# - Signing of app images and partition table data for Secure Boot can
# - Generating a signature sector and appending it to the image is an important step for securing firmware images.
# - It's recommended to use an external Hardware Security Module (HSM) to store private signing keys for added security.
# - Secure Boot options such as flash encryption, disabling of JTAG, BASIC ROM interpreter, and UART bootloader should be enabled for optimal security.
# - Key management is crucial and involves computing RSA-3072 public key pairs, storing them separately, and protecting the KEY_DIGEST
# - Bootloader and apps should be signed with private keys for security purposes.
# - The bootloader should be signed with all the private keys needed for the life of the device before flashing.
# - Multiple private keys can be used for signing apps only if one is being revoked.
# - Private keys should be signed independently and stored separately for added security.
# - Key revocation is a process of updating to a new key pair when a trusted private key has been compromised, and can be done either conserv
# - Key revocation is only applicable if secure boot is enabled and a key is revoked only when the signature verification fails.
# - Once a key is revoked, it can never be used again for verifying signatures of images, providing strong resistance against physical attacks but can brick the device permanently if all the keys are revoked.
# - The esp-idf build system can be used for secure boot, but it is possible to use the espsecure.py tool to make standalone signatures and digests.
# - It is recommended to
# - Secure Boot V2 is a feature that protects a device from running unauthorized code by verifying that each piece of software being booted is signed.
# - The system only verifies a signature block in the first position and ignores any other appended signatures.
# - Multiple trusted keys are supported with hardware Secure Boot, but only the first public key in the signature block is used to verify updates without Secure Boot.
# - It is highly recommended to use full hardware Secure Boot for better application security.
# - To enable app signing,
# - The ESP32-S3 has a secure boot process that verifies the validity of the bootloader and application image using RSA-PSS signatures.
# - Up to three public keys can be generated and stored in the chip, and they can be permanently revoked if necessary.
# - The device is immune to passive side-channel attacks because it doesn't store any secrets.
# - The Secure Boot V2 process verifies the bootloader and application binary images using a dedicated signature block, and the application image is verified on every boot and OTA
# - The ROM code executes the bootloader which verifies the application image's signature block and the image itself using the raw image data and the eFuse.
# - If the verification fails, the boot process is aborted, but the bootloader will try to find another image until a valid one is found or no more images are available.
# - The verified application image is then executed.
# - The signature block contains a magic byte, version number byte, padding bytes, SHA-256 hash of the image content,
# - Application image always starts on the next flash MMU page size boundary (default 64KB).
# - A signature block is valid if the first byte is 0xe7 and a valid CRC32 is stored at offset 1196.
# - An image is verified if the public key stored in any signature block is valid for this device and if the stored signature is valid for the image data read from flash.
# - Enabling Secure boot and/or flash encryption will increase the size of the bootloader.
# -
# - Secure Boot is a process to ensure firmware and software security on a device.
# - Unused key digest slots should be revoked to prevent an attacker from adding trusted keys later.
# - The signing key must be readable to give software access to it. If it's read-protected, it will be read as zeros and the boot process will fail.
# - Generating a signing key via espsecure.py may result in a weak key due to the source of the randomness used.
# - Using openssl or another industry-standard encryption
# - The ESP32-S3 chip can have Secure Boot enabled to verify the authenticity of the software bootloader and app image.
# - Secure Boot won't be enabled until after a valid partition table and app image have been flashed.
# - Any updated bootloader or app will need to be signed with a key matching the digest already stored in eFuse.
# - Enabling Secure Boot or flash encryption disables the USB-OTG USB stack in the ROM, disallowing updates via the serial emulation or Device
# - Secure Boot system strength depends on keeping the signing key private
# - It's good practice to use a remote signing server to sign app images and partition table data for Secure Boot
# - Disable the option CONFIG_SECURE_BOOT_BUILD_SIGNED_BINARIES and build the firmware to use remote signing
# - You can use espsecure.py command line program to sign app images & partition table data for Secure Boot remotely
# - Pre-calculated signatures can be used to generate a signature sector and append it to the image
# - The --append_signatures option allows up to 3 signatures to be added to an image.
# - The Secure Boot system should be kept secure at all times by generating keys on a system with a quality source of entropy and not allowing any third party to observe the key generation or signing process.
# - Between 1 and 3 RSA-3072 public key pairs should be computed independently and stored separately, with unused slots being disabled.
# - The bootloader should be signed with all the private keys that are
# - The article discusses a secure boot feature that minimizes the exposure of unused private keys when updating firmware on devices.
# - The bootloader can be signed with multiple keys from the factory to allow for updates in case one key becomes compromised.
# - The secure boot feature includes key revocation, which helps prevent physical attacks on the device.
# - The revocation feature can be enabled through burning SECURE_BOOT_AGGRESSIVE_REVOKE efuse or enabling CONFIG_SECURE_BOOT_ENABLE_AGGRESSIVE_KEY_REVOKE.
# - Using both hardware Secure Boot and OTA update signature checking is recommended for better security.
# - OTA update signature checking is useful when delay of Secure Boot on startup is unacceptable and when physical access or flash writing attacks aren't a threat.
# - A chain of trust is created from the currently running app to the newly updated app using the public key in the signature block.
# - The initial app flashed on the device must also be signed to prevent situations where no update is possible.
# - It's recommended to use full
# - This article discusses the importance of signing apps during or after the build process.
# - Enabling Secure Boot disables JTAG debugging via eFuse by default.
# - The bootloader enables Secure Boot and disables JTAG debugging on first boot.
# - Additional information on using JTAG debugging with Secure Boot or signed app verification is available in a linked article.
# - The article is from Espressif Systems, a tech company based in Shanghai.
